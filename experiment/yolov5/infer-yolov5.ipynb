# %% [markdown]
# # yolov5s.ptの推論テスト
#
# `yolov5s.pt`を用いて物体検出の推論を試すノートブック
#
# 具体的な検出対象は決まっていないが、とりあえず手元の画像で推論を行った記録

# %% [markdown]
# ## 環境セットアップ

# %%
# %cd /home/jinysd/workspace/repo/room-eye/external
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd yolov5
# !pip install -r requirements.txt

# %% [markdown]
# ## 重みファイルダウンロード

# %%
# %cd /home/jinysd/workspace/repo/room-eye/external/yolov5
# !mkdir weights 
# %cd ./weights
# !wget https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt
# %cd ..

# %% [markdown]
# ## 推論テスト

# %%
# !python3 detect.py \
--weights ./weights/yolov5s.pt \
--source ./data/images/Mel001.jpg
# Out:
# detect: weights=['./weights/yolov5s.pt'], source=./data/images/Mel001.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /home/jinysd/workspace/repo/room-eye/external/yolov5/data/images/Mel001.jpg: 640x480 1 dog, 43.7ms
# Speed: 1.6ms pre-process, 43.7ms inference, 190.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
import os
import glob
from IPython.display import Image, display

# 最新の runs/detect/exp フォルダを取得
exp_dir = max(glob.glob('runs/detect/exp'), key=os.path.getctime)

# その中の画像ファイルを全部取得
image_paths = glob.glob(os.path.join(exp_dir, '*.jpg'))

# 全部表示
for img_path in image_paths:
    display(Image(filename=img_path))

# %%
import os
import glob
from IPython.display import Image, display

# 最新の runs/detect/exp フォルダを取得
exp_dir = max(glob.glob('runs/detect/exp3'), key=os.path.getctime)

# その中の画像ファイルを全部取得
image_paths = glob.glob(os.path.join(exp_dir, '*.jpg'))

# 全部表示
for img_path in image_paths:
    display(Image(filename=img_path))
